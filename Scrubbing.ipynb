# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
    "/content/data.csv",
    sep=";",
    engine="python",
    on_bad_lines="skip"
)

print(df.shape)
df.head(6)
# Out:
# (29550, 48)
#   Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0      CHEMBL1573562           NaN                 NaN            420.88
# 1      CHEMBL1523269           NaN                 NaN            303.79
# 2      CHEMBL1506534           NaN                 NaN            359.41
# 3      CHEMBL1467135           NaN                 NaN            228.30
# 4      CHEMBL1523271           NaN                 NaN            273.32
# 5      CHEMBL1405511           NaN                 NaN            333.39
#
#    #RO5 Violations  AlogP Compound Key  \
# 0              0.0   2.40  SID24405141
# 1              0.0   2.11  SID24779084
# 2              0.0   1.76   SID7966081
# 3              0.0   2.25    SID858663
# 4              0.0   2.36  SID24782946
# 5              0.0   2.82   SID4248711
#
#                                              Smiles Standard Type  \
# 0  CC(C)c1nn2c(=O)cc(COC(=O)CNC(=O)c3ccccc3Cl)nc2s1       Potency
# 1               CC(C)(C)c1oc(C(=O)O)cc1CN1CCOCC1.Cl       Potency
# 2        CN(CC(=O)NCc1ccco1)S(=O)(=O)c1cccc2cccnc12       Potency
# 3                    Cc1cc2c(cc1C)-c1nnnn1C(C)(C)C2       Potency
# 4                  COc1ccc2nc3c(O)n4c(nc-3c2c1)SCC4       Potency
# 5             COCCNC(=O)c1cc2c(-c3ccccc3F)nn(C)c2s1       Potency
#
#   Standard Relation  ...  Document ChEMBL ID Source ID  Source Description  \
# 0               '='  ...       CHEMBL1201862         7   PubChem BioAssays
# 1               '='  ...       CHEMBL1201862         7   PubChem BioAssays
# 2               '='  ...       CHEMBL1201862         7   PubChem BioAssays
# 3               '='  ...       CHEMBL1201862         7   PubChem BioAssays
# 4               '='  ...       CHEMBL1201862         7   PubChem BioAssays
# 5               '='  ...       CHEMBL1201862         7   PubChem BioAssays
#
#   Document Journal Document Year Cell ChEMBL ID  Properties  Action Type  \
# 0              NaN           NaN            NaN         NaN          NaN
# 1              NaN           NaN            NaN         NaN          NaN
# 2              NaN           NaN            NaN         NaN          NaN
# 3              NaN           NaN            NaN         NaN          NaN
# 4              NaN           NaN            NaN         NaN          NaN
# 5              NaN           NaN            NaN         NaN          NaN
#
#    Standard Text Value    Value
# 0                  NaN   0.6310
# 1                  NaN  89.1251
# 2                  NaN  89.1251
# 3                  NaN  25.1189
# 4                  NaN   0.6310
# 5                  NaN   2.8184
#
# [6 rows x 48 columns]

# %% [markdown]
# Фильтрация по мишени AmpC

# %%
df = df[
    (df["Target ChEMBL ID"] == "CHEMBL2026") &
    (df["Target Name"].str.contains("Beta-lactamase", na=False))
].copy()

print("После фильтра по мишени:", df.shape)
# Out:
# После фильтра по мишени: (19316, 48)

# %% [markdown]
# Осмысленные активности

# %%
valid_types = ["IC50", "Ki", "Kd", "Potency", "pChEMBL Value"]

df = df[
    df["Standard Type"].isin(valid_types) |
    df["pChEMBL Value"].notna()
].copy()

print("После фильтра активности:", df.shape)
# Out:
# После фильтра активности: (19250, 48)

# %% [markdown]
# Очистка SMILES и парсинг RDKit

# %%
# !pip install rdkit
# Out:
# Requirement already satisfied: rdkit in /usr/local/lib/python3.12/dist-packages (2025.9.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors

# %%
def smiles_to_mol(smiles):
    try:
        return Chem.MolFromSmiles(smiles)
    except:
        return None

df["mol"] = df["Smiles"].apply(smiles_to_mol)

df = df[df["mol"].notna()].copy()
print("После удаления битых SMILES:", df.shape)
# Out:
# После удаления битых SMILES: (19245, 49)

# %% [markdown]
# Удаление нереалистичных соединений

# %%
df["MW"] = df["mol"].apply(Descriptors.MolWt)

df = df[
    (df["MW"] > 100) &
    (df["MW"] < 800)
].copy()

print("После фильтра MW:", df.shape)
# Out:
# После фильтра MW: (19226, 50)

# %% [markdown]
# Удаление нестабильных и реактивных структур

# %%
def unstable_structure(mol):
    patterns = [
        "[N+](=O)[O-]",        # нитросоединения
        "[SH]",               # свободные тиолы
        "[S-]",               # тиолаты
        "C=C=C",              # кумулированные системы
        "[O-][N+](=O)",       # нитраты
        "[Cl,Br,I][Cl,Br,I]"  # галоген-галоген
    ]
    for p in patterns:
        if mol.HasSubstructMatch(Chem.MolFromSmarts(p)):
            return True
    return False

df = df[~df["mol"].apply(unstable_structure)].copy()
print("После удаления нестабильных структур:", df.shape)
# Out:
# После удаления нестабильных структур: (18018, 50)

# %% [markdown]
# Удаление токсофоров

# %%
toxic_smarts = [
    "c1ccc(cc1)[N+](=O)[O-]",   # ароматические нитро
    "N=N",                      # азосоединения
    "[Hg,Pb,Cd]",               # тяжёлые металлы
    "[Se]",                     # селен
    "[As]"                      # мышьяк
]

def has_toxicophore(mol):
    for s in toxic_smarts:
        if mol.HasSubstructMatch(Chem.MolFromSmarts(s)):
            return True
    return False

df = df[~df["mol"].apply(has_toxicophore)].copy()
print("После удаления токсофоров:", df.shape)
# Out:
# После удаления токсофоров: (17969, 50)

# %% [markdown]
# drug-likeness фильтрация

# %%
df["logP"] = df["mol"].apply(Descriptors.MolLogP)
df["HBD"] = df["mol"].apply(Descriptors.NumHDonors)
df["HBA"] = df["mol"].apply(Descriptors.NumHAcceptors)
df["RB"]  = df["mol"].apply(Descriptors.NumRotatableBonds)

df = df[
    (df["logP"] < 6) &
    (df["HBD"] <= 5) &
    (df["HBA"] <= 10) &
    (df["RB"] <= 10)
].copy()

print("После drug-likeness фильтра:", df.shape)
# Out:
# После drug-likeness фильтра: (17495, 54)

# %%
final_cols = [
    "Molecule ChEMBL ID",
    "Smiles",
    "Standard Type",
    "Standard Value",
    "Standard Units",
    "pChEMBL Value",
    "MW", "logP", "HBD", "HBA", "RB"
]

df_final = df[final_cols].copy()
df_final.reset_index(drop=True, inplace=True)

print("Финальный датасет:", df_final.shape)
df_final.head()
# Out:
# Финальный датасет: (17495, 11)
#   Molecule ChEMBL ID                                            Smiles  \
# 0      CHEMBL1573562  CC(C)c1nn2c(=O)cc(COC(=O)CNC(=O)c3ccccc3Cl)nc2s1
# 1      CHEMBL1523269               CC(C)(C)c1oc(C(=O)O)cc1CN1CCOCC1.Cl
# 2      CHEMBL1506534        CN(CC(=O)NCc1ccco1)S(=O)(=O)c1cccc2cccnc12
# 3      CHEMBL1467135                    Cc1cc2c(cc1C)-c1nnnn1C(C)(C)C2
# 4      CHEMBL1523271                  COc1ccc2nc3c(O)n4c(nc-3c2c1)SCC4
#
#   Standard Type  Standard Value Standard Units  pChEMBL Value       MW  \
# 0       Potency           631.0             nM           6.20  420.878
# 1       Potency         89125.1             nM           4.05  303.786
# 2       Potency         89125.1             nM           4.05  359.407
# 3       Potency         25118.9             nM           4.60  228.299
# 4       Potency           631.0             nM           6.20  273.317
#
#       logP  HBD  HBA  RB
# 0  2.40100    1    8   6
# 1  2.52930    1    4   3
# 2  1.76470    1    5   6
# 3  2.24814    0    4   0
# 4  2.35600    1    6   1

# %%
cols_participants = [
    "Molecule ChEMBL ID",
    "Smiles",
    "Standard Type",
    "Standard Value",
    "Standard Units",
    "pChEMBL Value"
]

df_participants = df[cols_participants].copy()
df_participants.reset_index(drop=True, inplace=True)

print("Датасет для участников:", df_participants.shape)

df_participants.to_csv(
    "/content/dataset_participants.csv",
    index=False
)
# Out:
# Датасет для участников: (17495, 6)

# %%
cols_internal = [
    "Molecule ChEMBL ID",
    "Smiles",
    "Standard Type",
    "Standard Value",
    "Standard Units",
    "pChEMBL Value",
    "MW", "logP", "HBD", "HBA", "RB"
]

df_internal = df[cols_internal].copy()
df_internal.reset_index(drop=True, inplace=True)

print("Внутренний датасет:", df_internal.shape)

df_internal.to_csv(
    "/content/ampc_dataset_internal.csv",
    index=False
)
# Out:
# Внутренний датасет: (17495, 11)
